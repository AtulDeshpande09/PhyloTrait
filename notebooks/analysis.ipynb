# %%
path = "../data/selected_bacteria.fasta"

# %%
from Bio import SeqIO

# %%
sequences = list(SeqIO.parse(path , 'fasta'))

# %%
print(f"Loaded {len(sequences)} Sequences!!!")
# Out:
# Loaded 200 Sequences!!!

# %%
print("Sample Sequences : ")
print()
print("--+--"*10)
print()
for seq in sequences[:2]:
    print(seq)
    print()
    print("--+--"*10)
    print()
# Out:
# Sample Sequences :
#
# --+----+----+----+----+----+----+----+----+----+--
#
# ID: HG530068.754687.756210
# Name: HG530068.754687.756210
# Description: HG530068.754687.756210 Bacteria;Pseudomonadota;Gammaproteobacteria;Pseudomonadales;Pseudomonadaceae;Pseudomonas;Pseudomonas aeruginosa PA38182
# Number of features: 0
# Seq('AGAGUUUGAUCAUGGCUCAGAUUGAACGCUGGCGGCAGGCCUAACACAUGCAAG...CCU')
#
# --+----+----+----+----+----+----+----+----+----+--
#
# ID: AB002522.1.1416
# Name: AB002522.1.1416
# Description: AB002522.1.1416 Bacteria;Bacillota;Bacilli;Lactobacillales;Streptococcaceae;Streptococcus;Streptococcus pneumoniae
# Number of features: 0
# Seq('CCUAAUACAUGCAAGUAGAACGCUGAAGGAAGGAGCUUGCUUCUCUUGGAUGAG...AGG')
#
# --+----+----+----+----+----+----+----+----+----+--

# %%
import pandas as pd

# %%
path = "../data/traits.csv"
traits = pd.read_csv(path)
traits.head()
# Out:
#                      species gram_stain oxygen_tolerance     habitat  \
# 0           Escherichia_coli   negative      facultative   human_gut
# 1      Staphylococcus_aureus   positive      facultative  human_skin
# 2          Bacillus_subtilis   positive          aerobic        soil
# 3  Lactobacillus_acidophilus   positive        anaerobic   human_gut
# 4     Pseudomonas_aeruginosa   negative          aerobic       water
#
#   pathogenic antibiotic_resistance
# 0        yes              variable
# 1        yes                medium
# 2         no                   low
# 3         no                   low
# 4        yes                  high

# %% [markdown]
# ### 🛠️ Terminal Commands Used
#
# Below are the shell commands used during dataset creation and tree building.

# %% [markdown]
# - #### Download SILVA database
# ```bash
# wget https://example.com/SILVA_138.2_SSURef_NR99_03_07_24_opt.arb.gz
# ```
# ---
# - #### unzip the file
# ```bash
# gunzip SILVA_138.2_SSURef_NR99_03_07_24_opt.arb.gz
# ```
# ---
#
# - #### Extract sequences using custom script
#
# ```bash
# python extract_fasta.py
# ```
#
# ---
# - ##### Align sequences using MUSCLE
#
# ```bash
# muscle -in combined.fasta -out aligned.fasta
# ```
# ---
# - #### Build tree from aligned file
#
# ```bash
# python build_tree.py
# ```
# ---
# - #### Open iTOL for visualization
# - #### Upload tree.nwk at [https://itol.embl.de]
#
# ---

# %%
from IPython.display import Image

# %% [markdown]
# #### Tree Visualization ( sample screenshots )

# %%
Image(filename="../trees/tree.png")

# %%
Image(filename="../trees/tree_s1.png")

# %%
Image(filename="../trees/tree_s2.png")
